# %% [markdown]
# <a href="https://colab.research.google.com/github/athidevks-maker/resume-job-compatibility/blob/feature%2Fresume-processing/notebooks/02_resume_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -r requirements.txt
# !pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.5/395.5 kB 7.2 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/athidevks-maker/resume-job-compatibility.git
# %cd /content/resume-job-compatibility
# Out:
# Cloning into 'resume-job-compatibility'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 36 (delta 7), reused 24 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (36/36), 13.85 KiB | 1.98 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/resume-job-compatibility

# %%
from src.resume_processor import process_resume

pdf_path = "data/demo/demo_resume_athidev.pdf"

resume_data = process_resume(pdf_path)

print("Skills:", resume_data["skills"])
print("Experience:", resume_data["experience"])
print("Degree:", resume_data["degree"])
print("Field:", resume_data["field"])
# Out:
# Skills: ['python', 'java', 'c', 'javascript', 'html', 'css', 'django', 'rest api', 'mysql', 'postgresql', 'sql', 'pandas', 'numpy', 'machine learning', 'feature engineering', 'model evaluation', 'data preprocessing', 'data analysis', 'data science', 'docker', 'git', 'github', 'version control', 'linux', 'application development', 'software testing']
# Experience: 4.2
# Degree: btech
# Field: computer science
